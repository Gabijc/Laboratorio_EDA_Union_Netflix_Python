# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Pandas (EDA y Unión de Datos)
#
# ## Los datos
#
# Para este laboratorio, trabajarás con los siguientes conjuntos de datos:
#
# - **`netflix_originals.csv`**: Contiene información sobre producciones originales de Netflix. Las columnas que nos encontraremos en este conjunto de datos son:
#
#    - `Title`: Contiene el nombre del título de la producción original de Netflix.
#
#    - `Genre`: Especifica el género o combinación de géneros de la producción.
#
#    - `Premiere`: Indica la fecha de estreno de la producción en Netflix.
#
#    - `Runtime`: Contiene la duración de la producción en minutos.
#
#    - `IMDB Score`: Representa la calificación promedio que la producción ha recibido en la plataforma IMDB.
#
#    - `Language`: Especifica el idioma principal o los idiomas en los que se presenta la producción.
#
# - **`netflix_titles.csv`**: Contiene información sobre una variedad de títulos disponibles en la plataforma Netflix, incluyendo tanto películas como series de televisión. Las columnas que nos encontraremos en este conjunto de datos son:
#
#    - `show_id`: Identificador único para cada título en el dataset.
#
#    - `type`: Especifica el tipo de contenido, ya sea "Movie" (película) o "TV Show" (serie de televisión).
#
#    - `title`: Contiene el nombre del título de la producción.
#
#    - `director`: Muestra el nombre del director del título. Puede estar vacío en algunos casos.
#
#    - `cast`: Lista de actores y actrices que participaron en el título. También puede estar vacío en algunos casos.
#
#    - `country`: País o países donde se produjo el título. Esta columna también puede tener valores faltantes.
#
#    - `date_added`: Fecha en la que el título fue añadido al catálogo de Netflix.
#
#    - `release_year`: Año en que el título fue lanzado o producido.
#
#    - `rating`: Clasificación del contenido en términos de audiencia (por ejemplo, PG-13, TV-MA).
#
#    - `duration`: Duración del título. Para películas, se expresa en minutos (e.g., "90 min") y para series en temporadas (e.g., "2 Seasons").
#
#    - `listed_in`: Categorías o géneros bajo los cuales el título está clasificado (por ejemplo, "Documentaries", "TV Dramas").
#
#    - `description`: Breve sinopsis o descripción del contenido del título.
#
# A lo largo de los laboratorios de Pandas, trabajarás con estos conjuntos de datos (o con los derivados del Laboratorio), algunas de las actividades que realizaremos son:
#
# - Exploración de datos y análisis exploratorio (EDA) para familiarizarse con los conjuntos de datos.
#
# - Realización de uniones entre conjuntos de datos, aplicando diferentes técnicas de *merging* y analizando la relevancia de cada método.
#
# - Uso de funciones de selección y filtrado (`loc`, `iloc`) para extraer información clave.
#
# - Desarrollo de análisis descriptivos y visualización de patrones para comprender mejor las decisiones estratégicas de la plataforma.
#
# ----
#
# ## Objetivo General de la Serie de Laboratorios
#
#
#
# 1. **Unión de `netflix_titles.csv` con `netflix_originals.csv`:**
#
#    - **Análisis de contenido original:**  Identificarás los títulos que son producciones originales de Netflix y los compararás con los títulos adquiridos. Este análisis te permitirá:
#
#      - Comparar la diversidad de géneros entre los títulos originales y no originales.
#
#      - Evaluar si ciertos géneros o tipos de contenido (como documentales o series) son más frecuentes en las producciones originales.
#
#      - Investigar si la producción original se concentra en determinados países o idiomas.
#
#
#    - **Evaluación de contenido:** En esta etapa, explorarás si las producciones originales de Netflix tienden a recibir mejores o peores evaluaciones en comparación con el contenido adquirido. Algunas preguntas que se buscarán responder incluyen:
#
#      - ¿Los títulos originales tienen una calificación promedio superior en plataformas como IMDB?
#
#      - ¿Son las producciones originales más consistentes en términos de calidad percibida?
#
#      - ¿Existen diferencias en la popularidad de los títulos originales según su género o país de origen?
#
#
#    - **Identificación de tendencias:**  Por último, este análisis te permitirá explorar cómo ha evolucionado la estrategia de contenido de Netflix a lo largo del tiempo. Algunos puntos clave a investigar serán:
#
#      - ¿Cómo ha crecido la producción original en comparación con la adquisición de contenido?
#
#      - ¿Qué géneros o tipos de contenido han recibido mayor inversión en los últimos años?
#
#      - ¿Existen patrones en los países o idiomas de las producciones originales, especialmente en relación con la expansión global de Netflix?
#
#
# ----
#
#
# ## Ejercicio: Análisis y Enriquecimiento del Catálogo de Netflix
#
# ### Parte 1: Análisis Exploratorio de Datos (EDA)
#
# 1. **Carga de los datos:**
#
#    - Deberás cargar los dos conjuntos de datos que te hemos proporcionado para realizar este Laboratorio:
#
#      - `netflix_originals.csv`
#
#      - `netflix_titles.csv`
#
#    Deberás revisar la estructura de cada conjunto de datos utilizando los métodos aprendidos durante la lección.
#
# 2. **Análisis de columnas y consistencia:**
#
#    - Deberás hacer un análisis exploratorio de cada uno de los conjuntos de datos. Será obligatorio que incluyas las conclusiones generales obtenidas de cada uno de los análisis exploratorios en el Jupyter Notebook de tus soluciones.
#
#    - Explorar qué columnas contiene cada conjunto de datos y cuáles son sus tipos de datos. Identificar si hay valores nulos o duplicados.
#
#    - Algunas preguntas que nos podemos plantear en esta fase son (recuerda que esto es solo un ejemplo, y que podemos explorar todo lo que queramos/necesitemos para entender lo mejor posible los conjuntos de datos):
#
#       - ¿Cuáles son los tipos de datos de cada columna? Nos puede ayudar a detectar si algún tipo de dato está incorrectamente asignado, como fechas almacenadas como cadenas de texto.
#
#       - ¿Existen valores nulos? ¿En qué columnas están? Este paso es crucial para decidir si deben ser eliminados, rellenados o ignorados.
#
#       - ¿Cuántos títulos únicos hay en cada conjunto de datos? Nos puede permitir verificar si existen títulos duplicados que puedan distorsionar el análisis.
#
#       - ¿Qué géneros tenemos en el conjunto de datos? Esto nos puede ayudar a identificar los géneros más populares o incluso a identificar una posible limpieza de dicha columna para poder extraer conclusiones más claras en nuestro análisis.
#
# ### Parte 2: Unión de Datos
#
# 1. **Realización de la unión:**
#
#    - Deberás realizar la unión que consideres más apropiada entre `netflix_titles.csv` y `netflix_originals.csv`. Además, deberás justificar el tipo de unión que has realizado.
#
#    - Esto nos ayudará a contestar preguntas más adelente del tipo:
#
#      - ¿Cuántos títulos en `netflix_titles.csv` son producciones originales de Netflix?
#
#      - ¿Hay diferencias significativas en la puntuación de IMDB entre títulos originales y no originales?
#
# ### Parte 3: Uso de `loc` e `iloc`
#
# Usando el DataFrame creado en la Parte 2:
#
# 1. **Filtrado de datos con `loc`:**
#
#    - Selecciona todas las filas donde el tipo de contenido sea “Movie”.
#
#    - Muestra solo los títulos (title) y la duración (duration) de todos los contenidos que sean de tipo “TV Show”.
#
#    - Selecciona todas las filas donde el país sea “United States”.
#
#    - Muestra todas las películas (type = “Movie”) y selecciona las columnas title y director.
#
#    - Selecciona los títulos (title) y géneros (listed_in) de todas las producciones lanzadas en 2018.
#
#    - Selecciona las filas donde la columna director esté vacía y muestra solo los títulos (title).
#
# 2. **Acceso a datos específicos con `iloc`:**
#
#    - Selecciona las primeras 5 filas del conjunto de datos y muestra solo las columnas title, director y country.
#
#    - Muestra las últimas 5 filas del conjunto de datos y selecciona las columnas title y description.
#
#    - Selecciona las primeras 10 filas del dataset y muestra las columnas desde la segunda hasta la quinta (incluidas).
#
#    - Muestra las últimas 7 filas del dataset y selecciona las columnas title, director, y country usando índices posicionales.
#
#    - Selecciona las filas desde la 15 hasta la 25 (incluidas) y muestra las primeras 4 columnas.
#
#    - Muestra las filas 20 a 30 y solo las columnas title, release_year, y rating usando índices posicionales.
#
#
# **NOTA IMPORTANTE**: Antes de terminar el lab, guarda el conjunto de datos creado en la fase de unión para trabajar con el en las siguientes lecciones.

# %% [markdown]
# # Parte 1: Análisis exploratorio de datos

# %%
# librerias a usar
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
# Indicamos que nos muestre todas las columnas por pantalla cada vez que queramos mostrar un DataFrame

# %% [markdown]
# <p align="center"><strong>Importamos las bases de datos con las que vamos a trabajar</strong></p>

# %% [markdown]
# `netflix_originals.csv`

# %% [markdown]
# Importamos el documento con el método read_csv

# %%
# Importamos netflix_originals.csv mediante el método pd.read_csv
netflix_originals = pd.read_csv("datos/netflix_originals.csv", sep = ',', index_col = 0).reset_index(drop = True)
netflix_originals
# Le hemos indicado que nos cargue el archivo que contiene los datos sobre las producciones originales de Netflix, que me las separe por comas
# y que me coja como índice la columna cero (para que no me salga el Unnamed).
# Le pasamos el método reset.index para resetear el índice del DataFrame creado y usar el predeterminado por defecto, ya que cuando cargamos
# el Df, los índices iniciales no se corresponden con el total de registros que hay, sino que eran más.
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 508                       Cuba and the Cameraman            Documentary
# 509                       Dancing with the Birds            Documentary
# 510  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 511                      Springsteen on Broadway           One-man show
# 512     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %% [markdown]
# Creamos una copia de seguridad.

# %%
# Creamos una copia de la base para tenerla por si acaso en un futuro
copia_netflix_originals = netflix_originals.copy()
copia_netflix_originals
# Comprobamos que la copia se ha realizado de forma correcta.
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 508                       Cuba and the Cameraman            Documentary
# 509                       Dancing with the Birds            Documentary
# 510  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 511                      Springsteen on Broadway           One-man show
# 512     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %% [markdown]
# Vemos la forma y elementos que contiene

# %%
netflix_originals.shape
# Out:
# (513, 6)

# %% [markdown]
# La base de netflix_originals contiene 513 registros en total, contenidos en 6 columnas de información diferentes.

# %%
print("Los cinco primeros valores del dataframe son: \n ")
primeros_valores_originals = netflix_originals.head()
primeros_valores_originals
# Out:
# Los cinco primeros valores del dataframe son:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %%
print("Los cinco últimos valores del dataframe son: \n ")
segundos_valores_originals = netflix_originals.tail()
segundos_valores_originals
# Out:
# Los cinco últimos valores del dataframe son:
#                                            Title         Genre  \
# 508                       Cuba and the Cameraman   Documentary
# 509                       Dancing with the Birds   Documentary
# 510  Winter on Fire: Ukraine's Fight for Freedom   Documentary
# 511                      Springsteen on Broadway  One-man show
# 512     David Attenborough: A Life on Our Planet   Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# 508  November 24, 2017      114         8.3                   English
# 509   October 23, 2019       51         8.3                   English
# 510    October 9, 2015       91         8.4  English/Ukranian/Russian
# 511  December 16, 2018      153         8.5                   English
# 512    October 4, 2020       83         9.0                   English

# %%
print("Una muestra de valores del dataframe es: \n ")
muestra_df_originals = netflix_originals.sample(5)
muestra_df_originals
# Out:
# Una muestra de valores del dataframe es:
#                  Title                 Genre           Premiere  Runtime  \
# 200  The Kissing Booth       Romantic comedy       May 11, 2018      105
# 143   Out of Many, One           Documentary  December 12, 2018       34
# 207   Casting JonBenet           Documentary     April 28, 2017       80
# 79      Back to School                Comedy    August 30, 2019       83
# 183                Cam  Psychological horror  November 16, 2018       94
#
#      IMDB Score Language
# 200         6.0  English
# 143         5.7  English
# 207         6.1  English
# 79          5.3   French
# 183         5.9  English

# %% [markdown]
# `netflix_titles.csv`

# %% [markdown]
# Importamos el documento con el método read_csv.

# %%
# Importamos netflix_titles.csv mediante el método pd.read_csv
netflix_titles = pd.read_csv("datos/netflix_titles.csv", sep = ',', index_col = 0)
netflix_titles
# Le hemos indicado que nos cargue el archivo que contiene los datos sobre las producciones originales de Netflix, que me las separe por comas
# y que me coja como índice la columna cero (para que no me salga el Unnamed).
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Creamos una copia de seguridad.

# %%
# Creamos una copia de la base para tenerla por si acaso en un futuro.
copia_netflix_titles = netflix_titles.copy()
copia_netflix_titles
# Comprobamos que la copia se ha realizado de forma correcta.
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Vemos la forma y elementos que contiene

# %%
netflix_titles.shape
# Out:
# (8807, 12)

# %%
diferencia_pelis = netflix_titles.shape[0]-netflix_originals.shape[0] 
diferencia_pelis
# Queremos saber el número total de películas no originales de Netflix.
# Out:
# 8294

# %% [markdown]
# La base de netflix_titles contiene 8.807 registros en total, contenidos en 12 columnas de información diferentes. Hay 513 películas que son originales de Netlfix, y 8.294 películas que no son producciones originales de Netlfix.

# %%
print("Los cinco primeros valores del dataframe son: \n ")
primeros_valores_titles = netflix_titles.head()
primeros_valores_titles
# Out:
# Los cinco primeros valores del dataframe son:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
print("Los cinco últimos valores del dataframe son: \n ")
ultimos_valores_titles = netflix_titles.tail()
ultimos_valores_titles
# Out:
# Los cinco últimos valores del dataframe son:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
print("Una muestra de valores del dataframe es: \n ")
muestra_df_titles = netflix_titles.sample(5)
muestra_df_titles
# Out:
# Una muestra de valores del dataframe es:
#      show_id     type                                       title  \
# 2172   s2173    Movie                          Killing Hasselhoff
# 4941   s4942  TV Show                                        Troy
# 4579   s4580    Movie                           Kismat Konnection
# 2135   s2136  TV Show                         The Legend of Korra
# 6259   s6260    Movie  Beak & Brain: Genius Birds From Down Under
#
#                         director  \
# 2172                Darren Grant
# 4941                         NaN
# 4579                  Aziz Mirza
# 2135                         NaN
# 6259  Volker Arzt, Angelika Sigl
#
#                                                    cast  \
# 2172  Ken Jeong, David Hasselhoff, Jim Jefferies, Jo...
# 4941  Louis Hunter, Bella Dayne, Frances O'Connor, D...
# 4579  Shahid Kapoor, Vidya Balan, Juhi Chawla, Om Pu...
# 2135  Janet Varney, David Faustino, P.J. Byrne, J.K....
# ...

# %% [markdown]
# <p align="center"><strong>Realizamos un análisis de las columnas y datos de cada base</strong></p>

# %% [markdown]
# `netflix_originals.csv`

# %%
# Creamos una columna que me indique si la pelicula es o no original, para saber las que son originales para cuando realicemos una unión entre las dos bases
netflix_originals["es_original"] = "original" 
netflix_originals["es_original"].value_counts() # confirmamos que se ha creado correctamente y que tenemos 513 registros en esta columna.
# Out:
# es_original
# original    513
# Name: count, dtype: int64

# %% [markdown]
# Como hemos visto anteriormente, la base de películas originales de Netflix contiene 513 producciones. Las características proporcionadas en la base son: título, género, fecha de la premiere, duración (runtime), IMDB Score, idioma.

# %%
netflix_originals.columns
# Vemos las columnas que hay en la base
# Out:
# Index(['Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language',
#        'es_original'],
#       dtype='object')

# %%
netflix_originals.info()

# Mostramos información general sobre las columnas, como su nombre, nº total de registros de cada una, datos no nulos y tipo de dato que contienen
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        513 non-null    object
#  1   Genre        513 non-null    object
#  2   Premiere     513 non-null    object
#  3   Runtime      513 non-null    int64
#  4   IMDB Score   513 non-null    float64
#  5   Language     513 non-null    object
#  6   es_original  513 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 28.2+ KB

# %% [markdown]
# Queremos la misma información que tenemos en el DataFrame anterior, pero mejor vista visualmente, y con información añadida sobre los nulos por ejemplo. Para ello creamos una función a la que iremos añadiendo columnas que nos devolverán información sobre el Dataframe escogido.

# %%
def info_df(df):

    info_df = pd.DataFrame()
    info_df["Tipo_dato"] = df.dtypes
    info_df["numero_registros"] = [df[elemento].value_counts().sum() for elemento in df]
    info_df["Numero_nulos"] = round(df.isnull().sum())
    info_df["%_nulos"] = round((df.isnull().sum()/df.shape[0])*100, 2)
    #info_df["Duplicados"] = df.duplicated().sum()

    return info_df

# %%
info_df(netflix_originals)
# Out:
#             Tipo_dato  numero_registros  Numero_nulos  %_nulos
# Title          object               513             0      0.0
# Genre          object               513             0      0.0
# Premiere       object               513             0      0.0
# Runtime         int64               513             0      0.0
# IMDB Score    float64               513             0      0.0
# Language       object               513             0      0.0
# es_original    object               513             0      0.0

# %% [markdown]
# Información sobre las columnas que tenemos en la base:
# - `Title`: columna con índice 0, contiene 513 registros no nulos, de tipo no numérico (object).
# - `Genre`: columna con índice 1, contiene 513 registros no nulos, de tipo no numérico (object).
# - `Premiere`: columna con índice 2, contiene 513 registros no nulos, de tipo no numérico (object). Esta columna deberá tener un tipo de dato datetime, por lo que lo cambiamos a continuación.
# - `Runtime`: columna con índice 3, contiene 513 registros no nulos, de tipo numérico (int64).
# - `IMDB Score`: columna con índice 4, contiene 513 registros no nulos, de tipo numérico (float64).
# - `Language`: columna con índice 5, contiene 513 registros no nulos, de tipo no numérico (object).
#
# Como vemos, no hay ningún elemento nulo en la base, tenemos toda la información necesaria sobre las películas originales de Netflix.

# %%
# Queremos más información sobre los nulos en la base
nulos_originals = netflix_originals.isnull().sum()
nulos_originals
# Out:
# Title          0
# Genre          0
# Premiere       0
# Runtime        0
# IMDB Score     0
# Language       0
# es_original    0
# dtype: int64

# %% [markdown]
# No hay elementos nulos en ninguna de las columnas de nuestra base de películas originales de Netflix.

# %%
numero_duplicados_originals = netflix_originals.duplicated().sum()
print(f"Tenemos el siguiente número de duplicados iguales en la base de netflix_originals: {numero_duplicados_originals} ")
# Le hemos indicado que nos busque los duplicados que hay en la base, y nos haga una suma de los que haya.
# Out:
# Tenemos el siguiente número de duplicados iguales en la base de netflix_originals: 0

# %% [markdown]
# No hay elementos duplicados en `netflix_originals`.

# %% [markdown]
# Cambiamos el tipo de dato de la columna `Premiere`

# %%
#duda

# %% [markdown]
# **Anáisis estadístico de las columnas numéricas**

# %% [markdown]
# Cuando calculamos los estadísticos de una variable numérica mediante el método describe, nos calcula estadísticos básicos como la media, el mínimo y máximo, la desviación típica y los cuartiles. En nuestro caso nos interesa observar también los valores que toman la curtosis y el coeficiente de asimetría, por lo que los calcularemos. Nos creamos una función que nos incluya estos valores calculados a aquellos que ya devuelve de forma automática el método describe.

# %%
def estadísticos_numericas_df(df):
    valores_curtosis = []
    valores_asimetria = []
    valores_moda = []
    #creamos un bucle for para calcular los valores de la curtosis y la asimetría
    for columna in df:
        if df[columna].dtype == "int" or df[columna].dtype == "float":

            moda = df[columna].mode()    
            curtosis = round(df[columna].kurtosis(), 2)
            asimetria = round(df[columna].skew(),2)

            valores_moda.append(moda)
            valores_curtosis.append(curtosis)
            valores_asimetria.append(asimetria)
        else: 
            ...

    estadísticos_generales = df.describe().T 
    #estadísticos_generales["Curtosis"] = [df[columna].kurtosis() if df[columna].dtype == "int" or df[columna].dtype == "float" else ... for columna in df]
    estadísticos_generales["Moda"] = valores_moda
    estadísticos_generales["Curtosis"] = valores_curtosis
    estadísticos_generales["Coef_asimetria"] = valores_asimetria

    return estadísticos_generales

# %%
estadisticos_originales = estadísticos_numericas_df(netflix_originals)
estadisticos_originales
# Out:
#             count       mean        std  min   25%   50%    75%    max  \
# Runtime     513.0  94.674464  26.648121  4.0  87.0  97.0  108.0  209.0
# IMDB Score  513.0   6.210916   0.968850  2.5   5.6   6.3    6.9    9.0
#
#                                                  Moda  Curtosis  \
# Runtime           0    97
# Name: Runtime, dtype: int64      2.29
# IMDB Score  0    5.8
# Name: IMDB Score, dtype: float64      0.76
#
#             Coef_asimetria
# Runtime              -0.88
# IMDB Score           -0.52

# %% [markdown]
# Los estadísticos de las películas originales de Netlfix nos proporcionan la siguinte información:

# %% [markdown]
# *Runtime*
#
# La duración media de una película original de Netflix es de 94,97 minutos aproximadamente. Este dato se aproxima a la mediana, que tiene un valor de 97 minutos, por lo que podríamos decir que la media es un estadístico representativo de la muestra.
#
# La desviación típica presenta un valor de 26,64, es decir, habrá una diferencia en la duración media de las películas originales de Netflix cercana a la media hora. Esta variación podemos considerarla como significativa.
#
# Al analizar la simetría de los datos, nos fijamos que la media es menor a la mediana, por lo que tendremos asimetría a la izquierda, negativa, con un valor de -0,88. Los datos van a tender a estar situados en valores superiores, en duraciones mayores. La curtosis presenta un valor positivo, de 2,29, lo que indica que los datos tendrán una forma leptocúrtica, con datos más alejados de la media y concentrados en torno a valores concreatos.
#
# El rango de duración se encuentra entre los 4 minutos y los 209 minutos (3 h y 29 min), un rango bastante amplio. La moda se sitúa en los 97 minutos de duración. En cuanto a los cuartiles, un 25% de las películas tienen una duración por debajo de los 87 minutos, y un 75% de los datos tienen una duración por debajo de los 108 minutos.
#
# En el gráfico a continuación podemos ver la distribución de los datos visualmente. Vemos esa concentración de la duración en valores en torno a los 100 minutos, y la distribución a la derecha de los datos.

# %%
IQR_runtime = estadisticos_originales.iloc[0, 6] - estadisticos_originales.iloc[0, 4]
IQR_runtime
# Out:
# np.float64(21.0)

# %%
sns.histplot(x = "Runtime", data = netflix_originals, color = "olivedrab")
# Out:
# <Axes: xlabel='Runtime', ylabel='Count'>

# %% [markdown]
# Los estadísticos de la puntuación de IMDB de las películas originales de Netlfix nos proporcionan la siguinte información:

# %% [markdown]
# *IMDB Score*
#
# La puntuación media de una película original de Netflix proporcionada por los usuarios de IMDB es de 6,21 puntos. Este dato se aproxima a la mediana, que tiene un valor de 6,3 puntos, por lo que podríamos decir que la media es un estadístico representativo de la muestra.
#
# La desviación típica presenta un valor de 0,96 puntos, es decir, habrá una diferencia en la puntuación media de las películas originales de Netflix cercana a un punto. Esta variación podemos considerarla como no significativa.
#
# Al analizar la simetría de los datos, nos fijamos que la media es menor a la mediana, por lo que tendremos una pequeña asimetría a la izquierda, negativa, con un valor de -0,52. Los datos van a tender a estar situados en valores superiores, en puntuaciones mayores. La curtosis presenta un valor positivo, de 0,76, lo que indica que los datos tendrán una forma leptocúrtica, con datos más alejados de la media y concentrados en torno a valores concretos.
#
# El rango de puntuación se encuentra entre los 2,5 puntos hasta los 9 puntos, un rango bastante amplio. La moda se sitúa en los 5,8 puntos. En cuanto a los cuartiles, un 25% de las películas tienen una puntuación por debajo de los 2,5 puntos, y un 75% de los datos tienen una puntos por debajo de los 6,9 puntos. Vemos que las películas originales de Netflix no obtienen puntuaciones muy altas, sino que se encuentran cercanas a valores intermedios en una escala de 0 a 10. Sería interesante comparar la puntuación de las películas de esta plataforma con las de otras plataformas.
#
# En el gráfico a continuación podemos ver la distribución de los datos visualmente. Vemos esa concentración de la puntuación en valores en torno a los 6 puntos, y la distribución a la derecha de los datos.

# %%
IQR_runtime = round((estadisticos_originales.iloc[1, 6] - estadisticos_originales.iloc[1, 4]), 2)
IQR_runtime
# Out:
# np.float64(1.3)

# %%
sns.histplot(x = "IMDB Score", data = netflix_originals, color = "olivedrab")
# Out:
# <Axes: xlabel='IMDB Score', ylabel='Count'>

# %% [markdown]
# A continuación tenemos una imagen sobre la asimetría para poder entender mejor los datos.

# %% [markdown]
# ![imagen asimetría](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTeHtwZiMf0rKUTPZX565aTyFGRe8eOxr5ufX4YFZu2ZRNauIp9oUtSlqiSeMUq5NRj-g&usqp=CAU)

# %% [markdown]
# **Análisis descriptivo de las columnas categóricas**

# %%
netflix_originals.describe(include = "object").T
# Out:
#             count unique                                       top freq
# Title         513    513  David Attenborough: A Life on Our Planet    1
# Genre         513    106                               Documentary  132
# Premiere      513    350                          October 18, 2019    5
# Language      513     37                                   English  352
# es_original   513      1                                  original  513

# %% [markdown]
# Los estadísticos de las variables no numéricas de las películas originales de Netlfix nos proporcionan la siguinte información:

# %% [markdown]
# *Title*
#
# Dentro de las películas orgininales de Netflix observamos que no hay ningñun título que se repite.

# %% [markdown]
# *Genre*
#
# Dentro de las películas orgininales de Netflix observamos que tenemos 106 diferentes géneros, y el que más se repite es el documental, con 132 valores de pelícuñas de este tipo. A continuación incidamos los valores únicos. A los documentales le siguen las películas de géneros dramáticos, comedia, comedia romántica y thriller. Los géneros que menos se repiten son los de animación de navidad comedia y aventura, las de antología con comedia oscura, las de animación con ciencia ficción.

# %%
df_valores_genero = netflix_originals["Genre"].value_counts()
df_valores_genero
# Out:
# Genre
# Documentary                             132
# Drama                                    73
# Comedy                                   42
# Romantic comedy                          35
# Thriller                                 33
#                                        ...
# Action-adventure                          1
# Concert Film                              1
# Animation / Science Fiction               1
# Anthology/Dark comedy                     1
# Animation/Christmas/Comedy/Adventure      1
# Name: count, Length: 106, dtype: int64

# %% [markdown]
# *Language*
#
# Dentro de las películas orgininales de Netflix observamos que tenemos 37 diferentes idiomas disponible, y el que más se repite es el inglés, con 356 valores de películas en este idioma. A continuación incidamos los valores únicos. Al inglés le sigue las películas en hindi, en español, en francés y en italiano. Los idiomas menos encontrados son el mandarin con inglés, el ruso con ingles y ucraniano o el akano con inglés.

# %%
df_valores_lenguaje = netflix_originals["Language"].value_counts()
df_valores_lenguaje
# Out:
# Language
# English                       352
# Hindi                          28
# Spanish                        26
# French                         18
# Italian                        14
# Portuguese                      9
# Indonesian                      9
# Japanese                        5
# English/Spanish                 5
# Korean                          5
# Turkish                         4
# German                          4
# Marathi                         3
# Polish                          3
# English/Japanese                2
# Dutch                           2
# Filipino                        2
# Thai                            2
# English/Hindi                   2
# Norwegian                       1
# Malay                           1
# Swedish                         1
# Spanish/Basque                  1
# English/Swedish                 1
# Spanish/Catalan                 1
# English/Taiwanese/Mandarin      1
# Thia/English                    1
# ...

# %% [markdown]
# *Premiere*
#
# Hasta que no cambiemos el tipo de dato de esta columna poco análisis podremos realizar

# %% [markdown]
# `netflix_titles.csv`

# %%
netflix_titles.columns
# Vemos las columnas que hay en la base
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_titles.info()
# Mostramos información general sobre als columnas, como su nombre, nº total de registros de cada una, datos no nulos y tipo de dato que contienen
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      3994 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
info_df(netflix_titles)
# Out:
#              Tipo_dato  numero_registros  Numero_nulos  %_nulos
# show_id         object              8807             0     0.00
# type            object              8807             0     0.00
# title           object              8807             0     0.00
# director        object              6173          2634    29.91
# cast            object              7982           825     9.37
# country         object              7976           831     9.44
# date_added      object              8797            10     0.11
# release_year     int64              8807             0     0.00
# rating          object              8803             4     0.05
# duration        object              3994          4813    54.65
# listed_in       object              8807             0     0.00
# description     object              8807             0     0.00

# %% [markdown]
# Información sobre las columnas que tenemos en la base:
#
# - `Show_id`: columna con índice 0, contiene 0 registros nulos, de tipo no numérico (object).
# - `Type`: columna con índice 1, contiene 0 registros nulos, de tipo no numérico (object).
# - `Title`: columna con índice 2, contiene registros nulos, de tipo no numérico (object).
# - `Director`: columna con índice 3, contiene 2.634 registros nulos, de tipo no numérico (object). Los registros nulos representan un 29,91 % del total de los datos, una proporción alta. Será necesario revisar la información de esta columna para ver tratamiento de los nulos.
# - `Cast`: columna con índice 4, contiene 825 registros nulos, de tipo no numérico (object). Los registros nulos representan un 9,91 % del total de los datos, una proporción no muy alta. Será necesario revisar la información de esta columna para ver tratamiento de los nulos.
# - `Country`: columna con índice 5, contiene 831 registros nulos, de tipo no numérico (object). Los registros nulos representan un 9,44 % del total de los datos, una proporción no muy alta. Será necesario revisar la información de esta columna para ver tratamiento de los nulos.
# - `Date_added`: columna con índice 6, contiene 10 registros nulos, de tipo no numérico (object). Los registros nulos representan un 0,11 % del total de los datos, una proporción muy baja. Será necesario revisar la información de esta columna para ver tratamiento de los nulos. Además se debe cambiar el tipo de dato que hay en la columna, a datetime.
# - ` Release_year`: columna con índice 7, contiene 0 registros nulos, de tipo numérico (int64).
# - ` Rating`: columna con índice 8, contiene 4 registros nulos, de tipo no numérico (object). Los registros nulos representan un 0,05 % del total de los datos, una proporción muy baja. Será necesario revisar la información de esta columna para ver tratamiento de los nulos. Además se debe cambiar el tipo de dato que hay en la columna, a int, ya que estamos ante números y será necesario para poder realizar un análisis descriptivo correcto.
# - `Duration`: columna con índice 9, contiene 4.813 registros nulos, de tipo no numérico (object).  Los registros nulos representan un 54,65 % del total de los datos, una proporción muy alta. Será necesario revisar la información de esta columna para ver tratamiento de los nulos. Además se debe cambiar el tipo de dato que hay en la columna, a int, ya que estamos ante números y será necesario para poder realizar un análisis descriptivo correcto.
# - `Listed_in`: columna con índice 10, contiene 0 registros nulos, de tipo no numérico (object).
# - `Description`: columna con índice 11, contiene 0 registros nulos, de tipo no numérico (object).

# %%
# Queremos más información sobre los nulos en la base
nulos_titles = netflix_titles.isnull().sum()
nulos_titles
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration        4813
# listed_in          0
# description        0
# dtype: int64

# %%
numero_duplicados_titles = netflix_titles.duplicated().sum()
print(f"Tenemos el siguiente número de duplicados iguales en la base de netflix_titles: {numero_duplicados_titles} ")
# Le hemos indicado que nos busque los duplicados que hay en la base, y nos haga una suma de los que haya.
# Out:
# Tenemos el siguiente número de duplicados iguales en la base de netflix_titles: 0

# %% [markdown]
# Los estadísticos de las variables numércias de las películas de Netlfix nos proporcionan la siguinte información:

# %%
estadísticos_numericas_df(netflix_titles)
# Out:
#                count         mean       std     min     25%     50%     75%  \
# release_year  8807.0  2014.180198  8.819312  1925.0  2013.0  2017.0  2019.0
#
#                  max                                        Moda  Curtosis  \
# release_year  2021.0  0    2018
# Name: release_year, dtype: int64     16.23
#
#               Coef_asimetria
# release_year           -3.45

# %% [markdown]
# *Release Year*
#
# De media el año en el que las películas de Netflix fueron sacadas fue 2014, y el dato central de la distribución de los años de salida de una película se encuentra en 2017 (mediana). Un 25 % de las películas fueron sacadas antes de 2013, y un 75% fueron sacadas antes de 2019. Solo tendremos un 25% de películas que salieron después de 2019. El rango de fechas de salida de las películas se encuentra entre 1925 y 2021. Sin embargo la mayoría de las películas se empiezan a sacar a partir de los 2000, como vemos en el gráfico a continuación. Esta casuística puede deberse a que a partir de 2006/2007 fue cuando Netflix se empezó a hacer con el control del mercado del streaming, dejando de lado a su mayor competidor, Blockbuster. Fue a partir de esas fechas cuando empezaron a implementar medidas que se adptaban a los gustos de loc consumidores, lo que puede que provocase que se empezasen a meter películas del momento por ejemplo, ya que son las que los consumidores querían ver.

# %%
sns.histplot(x = "release_year", data = netflix_titles, color = "olivedrab")
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>

# %% [markdown]
# Los estadísticos de las variables no numéricas de las películas de Netlfix nos proporcionan la siguinte información:

# %%
netflix_titles.describe(include = "object").T
# Out:
#             count unique                                                top  \
# show_id      8807   8807                                              s8807
# type         8807      2                                              Movie
# title        8807   8807                                             Zubaan
# director     6173   4528                                      Rajiv Chilaka
# cast         7982   7692                                 David Attenborough
# country      7976    748                                      United States
# date_added   8797   1767                                    January 1, 2020
# rating       8803     17                                              TV-MA
# duration     3994    185                                          2 Seasons
# listed_in    8807    514                       Dramas, International Movies
# description  8807   8775  Paranormal activity at a lush, abandoned prope...
#
#              freq
# show_id         1
# ...

# %% [markdown]
# *Show_id*
#
# Dentro de las películas de Netflix observamos que no hay ninguna producción que se repite.
#
#
# *Title*
#
# Dentro de las películas orgininales de Netflix observamos que no hay ningñun título que se repite.

# %% [markdown]
# *Type*
#
# Dentro de las producciones en la base de Netflix, tenemos que pueden ser de dos tipos, o películas o series de televisión. Prredominan las películas, hay 6.131 produccines que son películas, el resto son series.

# %%
netflix_titles["type"].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %% [markdown]
# *Director*
#
# Dentro de las producciones en la base de Netflix, hay 4.528 directores diferentes. El director que aparece en más películas es Rajiv Chilaka. Aún así, hay un alto número de producciones de las cuales no se sabe su director.

# %% [markdown]
# *Cast*
#
# Dentro de las producciones en la base de Netflix, hay 7.962 actores diferentes. El actor que aparece en más películas es David Attenborough. Aún así, hay un alto número de producciones de las cuales no se sabe su director.
#
# *Tener en cuenta que hay un count más alto que valores únicos. Entendemos que cuenta los valores únicos aunque en una misma celda haya varios actores, contará por actores en cada celda, no por valores en general.

# %% [markdown]
# *Country*
#
# Dentro de las producciones en la base de Netflix, tenemos 748 países en los que se han producido las producciones. El país que más producciones ha realizado es Estados Unidos, con un total de 2.818 producciones. Aún así, hay un alto número de producciones de las cuales no se sabe su país de producción original.

# %% [markdown]
# *Date_added*
#
# Dentro de las producciones en la base de Netflix, las producciones han sido añadidas a la plataforma en 1767 fechas diferentes. Importante hacer cambio de tipo de dato de esta columna para poder realizar un análisis detallado. La fecha en la que más producciones han sido añadidas ha sido 2020.

# %% [markdown]
# *Rating*
#
# Dentro de las producciones en la base de Netflix, tenemos 17 puntuaciones diferentes, siendo la más repetida la de TV-MA. Pendiente saber que significa cada tipo de rating.

# %%
netflix_titles.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# *Duration*
#
# Esta columna no tiene un análisis pertinente realizado hasta que no se cambie el tipo de dato que contiene a int.

# %% [markdown]
# *Listed_in*
#
# Dentro de las producciones en la base de Netflix, tenemos 514 género diferentes. El género que más se repite es el de Dramas, International Movies.

# %%
netflix_titles.listed_in.unique()
# Out:
# array(['Documentaries', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'Docuseries, Reality TV',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'TV Dramas, TV Horror, TV Mysteries', 'Children & Family Movies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'TV Comedies, TV Dramas', 'Documentaries, International Movies',
#        'Crime TV Shows, Spanish-Language TV Shows, TV Dramas',
#        'Thrillers',
#        'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure',
#        'International TV Shows, TV Action & Adventure, TV Dramas',
# ...

# %% [markdown]
# *Description*
#
# Dentro de las producciones en la base de Netflix, tenemos 8.775 descripciones diferentes. Esto no tiene sentido, ya que hay más descripciones que películas.

# %% [markdown]
# # Parte 2: Unión de datos

# %% [markdown]
# **Realizamos una unión entre ambas bases**
#
# Para unir ambas bases y tener toda la información en una misma base vamos a hacer uso del merge. En concreto left merge mediante las columnas de título de la película.

# %%
netflix_titles.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix_titles = netflix_titles.rename(columns={'title': 'Title'})
netflix_titles
# Out:
#      show_id     type                  Title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_final = netflix_titles.merge(netflix_originals, how = "left", on = "Title")
netflix_final
# Out:
#      show_id     type                  Title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Hay columnas de ambas bases que contienen la misma información, por lo que interpretamos que se podrían unir y dejarlo como una sola columna. Antes de esto es necesario comprobar que la información en ambas columnas sea la misma. Para ello vamos a coger las columnas que querríamos unir, y comprobamos si la información de las originales es la misma en ambos casos. Lo hacemos mediante un sample de los datos que podremos ir recorriendo runneandolo diferentes veces. Observaremos que no son iguales los datos en todos los casos, o que son parecidos pero no iguales.
#
# *pendiente saber como tratar esto

# %%
netflix_final[["duration", "Runtime", "es_original"]].sample(10)
# Out:
#        duration  Runtime es_original
# 4774     71 min      NaN         NaN
# 8194     80 min      NaN         NaN
# 6768        NaN      NaN         NaN
# 4763        NaN      NaN         NaN
# 6702        NaN      NaN         NaN
# 5018     47 min      NaN         NaN
# 613     112 min      NaN         NaN
# 1025        NaN      NaN         NaN
# 4119  2 Seasons      NaN         NaN
# 8745        NaN      NaN         NaN

# %%
netflix_final[["Genre", "listed_in", "es_original"]].sample(10)
# Out:
#              Genre                                          listed_in  \
# 3625           NaN                       Dramas, International Movies
# 7479           NaN                                             Dramas
# 6457           NaN  International TV Shows, Korean TV Shows, Reali...
# 2159  Dance comedy                                           Comedies
# 7654           NaN                    Documentaries, Music & Musicals
# 3298           NaN  Crime TV Shows, International TV Shows, Spanis...
# 4633           NaN               Anime Series, International TV Shows
# 3261           NaN                       Dramas, International Movies
# 8704           NaN                                          Thrillers
# 6765           NaN           Action & Adventure, International Movies
#
#      es_original
# 3625         NaN
# 7479         NaN
# 6457         NaN
# 2159    original
# 7654         NaN
# 3298         NaN
# 4633         NaN
# 3261         NaN
# 8704         NaN
# ...

# %%
netflix_final["es_original"].value_counts()
# Out:
# es_original
# original    513
# Name: count, dtype: int64

# %% [markdown]
# Hay 513 títulos originales en Netflix, y 8294 no originales.

# %%
netflix_final.shape
# Out:
# (8807, 18)

# %% [markdown]
# **¿Hay diferencias significativas en la puntuación de IMDB entre títulos originales y no originales?**
#
# No se puede realizar una comparativa entre la puntuación de IMDB de los títulos originales y no originales ya que los ´titulos que no son originales en netflix no tienen una puntuación de este tipo. En todo caso se podría realizar una comparación entre el rating de las originales y las no originales.

# %%
print(netflix_final["IMDB Score"].value_counts().sum()) 
print(netflix_final["rating"].value_counts().sum())
# Out:
# 513
# 8803

# %% [markdown]
# # Parte 3: Uso de `loc` e `iloc`

# %%
netflix_final.head()
# Out:
#   show_id     type                  Title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# **Filtrado de datos con `loc`**

# %% [markdown]
# Selecciona todas las filas donde el tipo de contenido sea "Movie".

# %%
netflix_final.loc[netflix_final["type"] == "Movie" , "type"]
# Out:
# 0       Movie
# 6       Movie
# 7       Movie
# 9       Movie
# 12      Movie
#         ...
# 8801    Movie
# 8802    Movie
# 8804    Movie
# 8805    Movie
# 8806    Movie
# Name: type, Length: 6131, dtype: object

# %% [markdown]
# Muestra solo los títulos (title) y la duración (duration) de todos los contenidos que sean de tipo “TV Show”.

# %%
filtro_TV_show = netflix_final["type"] == "TV Show"
netflix_final.loc[ filtro_TV_show, ["Title","duration"]]
# Out:
#                       Title   duration
# 1             Blood & Water  2 Seasons
# 2                 Ganglands        NaN
# 3     Jailbirds New Orleans        NaN
# 4              Kota Factory  2 Seasons
# 5             Midnight Mass        NaN
# ...                     ...        ...
# 8795        Yu-Gi-Oh! Arc-V  2 Seasons
# 8796             Yunus Emre  2 Seasons
# 8797              Zak Storm        NaN
# 8800     Zindagi Gulzar Hai        NaN
# 8803            Zombie Dumb  2 Seasons
#
# [2676 rows x 2 columns]

# %% [markdown]
# Selecciona todas las filas donde el país sea “United States”.

# %%
netflix_final.loc[netflix_final["country"] == "United States","country"]
# Out:
# 0       United States
# 9       United States
# 15      United States
# 27      United States
# 28      United States
#             ...
# 8791    United States
# 8793    United States
# 8802    United States
# 8804    United States
# 8805    United States
# Name: country, Length: 2818, dtype: object

# %% [markdown]
# Muestra todas las películas (type = “Movie”) y selecciona las columnas title y director.

# %%
filtro_Movie = netflix_final["type"] == "Movie"
netflix_final.loc[ filtro_Movie, ["Title","director"]]
# Out:
#                                  Title                       director
# 0                 Dick Johnson Is Dead                Kirsten Johnson
# 6     My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7                              Sankofa                   Haile Gerima
# 9                         The Starling                 Theodore Melfi
# 12                        Je Suis Karl            Christian Schwochow
# ...                                ...                            ...
# 8801                           Zinzana                Majid Al Ansari
# 8802                            Zodiac                  David Fincher
# 8804                        Zombieland                Ruben Fleischer
# 8805                              Zoom                   Peter Hewitt
# 8806                            Zubaan                    Mozez Singh
#
# [6131 rows x 2 columns]

# %% [markdown]
# Selecciona los títulos (title) y géneros (listed_in) de todas las producciones lanzadas en 2018.

# %%
filtro_2018 = netflix_final["release_year"] > 2018
netflix_final.loc[ filtro_2018, ["Title","listed_in"]]
# Out:
#                             Title  \
# 0            Dick Johnson Is Dead
# 1                   Blood & Water
# 2                       Ganglands
# 3           Jailbirds New Orleans
# 4                    Kota Factory
# ...                           ...
# 8516    The Spy Who Fell to Earth
# 8631  Trixie Mattel: Moving Parts
# 8718       Westside vs. the World
# 8752                     Wish Man
# 8756                    Woodstock
#
#                                               listed_in
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8516                Documentaries, International Movies
# 8631                    Documentaries, Music & Musicals
# ...

# %% [markdown]
# Selecciona las filas donde la columna director esté vacía y muestra solo los títulos (title).

# %%
filtro_director_nulos = netflix_final["director"].isnull()
netflix_final.loc[ filtro_director_nulos, "Title"]
# Out:
# 1                             Blood & Water
# 3                     Jailbirds New Orleans
# 4                              Kota Factory
# 10      Vendetta: Truth, Lies and The Mafia
# 14          Crime Stories: India Detectives
#                        ...
# 8795                        Yu-Gi-Oh! Arc-V
# 8796                             Yunus Emre
# 8797                              Zak Storm
# 8800                     Zindagi Gulzar Hai
# 8803                            Zombie Dumb
# Name: Title, Length: 2634, dtype: object

# %% [markdown]
# **Filtrado de datos con `iloc`**

# %% [markdown]
# Selecciona las primeras 5 filas del conjunto de datos y muestra solo las columnas title, director y country.

# %%
netflix_final.iloc[:5, [2, 3, 5]]
# Out:
#                    Title         director        country
# 0   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1          Blood & Water              NaN   South Africa
# 2              Ganglands  Julien Leclercq            NaN
# 3  Jailbirds New Orleans              NaN            NaN
# 4           Kota Factory              NaN          India

# %% [markdown]
# Muestra las últimas 5 filas del conjunto de datos y selecciona las columnas title y description.

# %%
netflix_final.iloc[-5:, [2, 11]]
# Out:
#             Title                                        description
# 8802       Zodiac  A political cartoonist, a crime reporter and a...
# 8803  Zombie Dumb  While living alone in a spooky town, a young g...
# 8804   Zombieland  Looking to survive in a world taken over by zo...
# 8805         Zoom  Dragged from civilian life, a former superhero...
# 8806       Zubaan  A scrappy but poor boy worms his way into a ty...

# %% [markdown]
# Selecciona las primeras 10 filas del dataset y muestra las columnas desde la segunda hasta la quinta (incluidas).

# %%
netflix_final.iloc[:10, 1:5]
# Out:
#       type                             Title                       director  \
# 0    Movie              Dick Johnson Is Dead                Kirsten Johnson
# 1  TV Show                     Blood & Water                            NaN
# 2  TV Show                         Ganglands                Julien Leclercq
# 3  TV Show             Jailbirds New Orleans                            NaN
# 4  TV Show                      Kota Factory                            NaN
# 5  TV Show                     Midnight Mass                  Mike Flanagan
# 6    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    Movie                           Sankofa                   Haile Gerima
# 8  TV Show     The Great British Baking Show                Andy Devonshire
# 9    Movie                      The Starling                 Theodore Melfi
#
#                                                 cast
# 0                                                NaN
# ...

# %% [markdown]
# Muestra las últimas 7 filas del dataset y selecciona las columnas title, director, y country usando índices posicionales.

# %%
netflix_final.iloc[-7:, [2, 3, 5]]
# Out:
#                    Title         director                       country
# 8800  Zindagi Gulzar Hai              NaN                      Pakistan
# 8801             Zinzana  Majid Al Ansari  United Arab Emirates, Jordan
# 8802              Zodiac    David Fincher                 United States
# 8803         Zombie Dumb              NaN                           NaN
# 8804          Zombieland  Ruben Fleischer                 United States
# 8805                Zoom     Peter Hewitt                 United States
# 8806              Zubaan      Mozez Singh                         India

# %% [markdown]
# Selecciona las filas desde la 15 hasta la 25 (incluidas) y muestra las primeras 4 columnas.

# %%
netflix_final.iloc[15:25, :4]
# Out:
#    show_id     type                                              Title  \
# 15     s16  TV Show                                  Dear White People
# 16     s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17     s18  TV Show                                    Falsa identidad
# 18     s19    Movie                                          Intrusion
# 19     s20  TV Show                                             Jaguar
# 20     s21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
# 21     s22  TV Show                             Resurrection: Ertugrul
# 22     s23    Movie                                    Avvai Shanmughi
# 23     s24    Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
# 24     s25    Movie                                              Jeans
#
#                                          director
# 15                                            NaN
# 16  Pedro de Echave García, Pablo Azorín Williams
# ...

# %% [markdown]
# Muestra las filas 20 a 30 y solo las columnas title, release_year, y rating usando índices posicionales.

# %%
netflix_final.iloc[20:31, [2, 7, 8]]
# Out:
#                                               Title  release_year rating
# 20  Monsters Inside: The 24 Faces of Billy Milligan          2021  TV-14
# 21                           Resurrection: Ertugrul          2018  TV-14
# 22                                  Avvai Shanmughi          1996  TV-PG
# 23     Go! Go! Cory Carson: Chrissy Takes the Wheel          2021   TV-Y
# 24                                            Jeans          1998  TV-14
# 25                             Love on the Spectrum          2021  TV-14
# 26                                   Minsara Kanavu          1997  TV-PG
# 27                                        Grown Ups          2010  PG-13
# 28                                       Dark Skies          2013  PG-13
# 29                                         Paranoia          2013  PG-13
# 30                                  Ankahi Kahaniya          2021  TV-14

# %% [markdown]
# Guardamos el dataset de trabajo como un csv

# %%
netflix_final.to_csv('datos/netflix_final.csv', index=False)
